# %% [markdown]
# ### 🌍 Geospatial Analysis
#
# This notebook presents a geospatial analysis of the **Power System Faults Dataset**, available on [Kaggle](https://www.kaggle.com/datasets/ziya07/power-system-faults-dataset). The dataset contains synthetic records of electrical power system faults across various geographic locations and weather conditions, designed for analysis, pattern recognition, and reliability prediction.
#
# #### 📄 Dataset Description
#
# Each row in the dataset represents a unique power system fault incident and includes information such as:
#
# - **Fault Type** (e.g., Line Breakage, Transformer Failure)
# - **Geographic Location** (Latitude & Longitude)
# - **Environmental Conditions** (Temperature, Wind Speed, Weather)
# - **Electrical Measurements** (Voltage, Current, Power Load)
# - **Fault Duration and Downtime**
# - **Maintenance and Component Health Status**

# %%
# 📥 Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster, HeatMap
from scipy.stats import skew, kurtosis
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ***
# ### 📥 Load the dataset from URL

# %%
url = 'https://raw.githubusercontent.com/Dr-AlaaKhamis/ISE518/refs/heads/main/datasets/fault_data.csv'
df = pd.read_csv(url)

df.head()
# Out:
#   Fault ID           Fault Type Fault Location (Latitude, Longitude)  \
# 0     F001        Line Breakage                 (34.0522, -118.2437)
# 1     F002  Transformer Failure                   (34.056, -118.245)
# 2     F003          Overheating                  (34.0525, -118.244)
# 3     F004        Line Breakage                   (34.055, -118.242)
# 4     F005  Transformer Failure                  (34.0545, -118.243)
#
#    Voltage (V)  Current (A)  Power Load (MW)  Temperature (C)  \
# 0         2200          250               50               25
# 1         1800          180               45               28
# 2         2100          230               55               35
# 3         2050          240               48               23
# 4         1900          190               50               30
#
#    Wind Speed (km/h) Weather Condition Maintenance Status Component Health  \
# 0                 20             Clear          Scheduled           Normal
# 1                 15             Rainy          Completed           Faulty
# 2                 25         Windstorm            Pending       Overheated
# 3                 10             Clear          Completed           Normal
# 4                 18             Snowy          Scheduled           Faulty
#
#    Duration of Fault (hrs)  Down time (hrs)
# 0                      2.0              1.0
# 1                      3.0              5.0
# 2                      4.0              6.0
# 3                      2.5              3.0
# 4                      3.5              4.0

# %% [markdown]
# #### 📂 Load dataset from local folder

# %%
# df = pd.read_csv("data/fault_data.csv")

# df.head()

# %% [markdown]
# ***
# ### Visualize data on a folium map with popup labels and power plant icons

# %%
# Parse lat/lon from the string column
df[['Latitude', 'Longitude']] = df['Fault Location (Latitude, Longitude)']\
    .str.replace('[()]', '', regex=True).str.split(', ', expand=True).astype(float)

# Create base map
map1 = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

# Add markers with labels
for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=folium.Popup(f"""
            <b>ID:</b> {row['Fault ID']}<br>
            <b>Type:</b> {row['Fault Type']}<br>
            <b>Voltage:</b> {row['Voltage (V)']} V<br>
            <b>Current:</b> {row['Current (A)']} A<br>
            <b>Load:</b> {row['Power Load (MW)']} MW
        """, max_width=300),
        icon=folium.Icon(color="blue", icon="bolt", prefix="fa")
    ).add_to(map1)

# map1.save("folium_power_plant_map.html")
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b6101db0767f07f7becda18e32e9af9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b6101db0767f07f7becda18e32e9af9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b6101db0767f07f7becda18e32e9af9 = L.map(
#                 &quot;map_9b6101db0767f07f7becda18e32e9af9&quot;,
#                 {
#                     center: [34.49962312252965, -118.48780849802372],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d904df71d7c7efd491523bab86124cf8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d904df71d7c7efd491523bab86124cf8.addTo(map_9b6101db0767f07f7becda18e32e9af9);
#
#
#             var marker_5a922e7111d44ac814fc206d822aa61d = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(map_9b6101db0767f07f7becda18e32e9af9);
#
#
#             var icon_652b9834c235b89c275dddc1d9bc102d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f7c47ea11bdd9b2db31c062eaec62272 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2739d899a393eafdcfb1544172f153cd = $(`&lt;div id=&quot;html_2739d899a393eafdcfb1544172f153cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;b&gt;ID:&lt;/b&gt; F001&lt;br&gt;             &lt;b&gt;Type:&lt;/b&gt; Line Breakage&lt;br&gt;             &lt;b&gt;Voltage:&lt;/b&gt; 2200 V&lt;br&gt;             &lt;b&gt;Current:&lt;/b&gt; 250 A&lt;br&gt;             &lt;b&gt;Load:&lt;/b&gt; 50 MW         &lt;/div&gt;`)[0];
#                 popup_f7c47ea11bdd9b2db31c062eaec62272.setContent(html_2739d899a393eafdcfb1544172f153cd);
#
#
#
#         marker_5a922e7111d44ac814fc206d822aa61d.bindPopup(popup_f7c47ea11bdd9b2db31c062eaec62272)
#         ;
#
#
#
#
#                 marker_5a922e7111d44ac814fc206d822aa61d.setIcon(icon_652b9834c235b89c275dddc1d9bc102d);
#
#
#             var marker_2ea2c2de29bd89017e76f500eb1e2a53 = L.marker(
#                 [34.056, -118.245],
#                 {
# }
#             ).addTo(map_9b6101db0767f07f7becda18e32e9af9);
#
#
#             var icon_8b1f7bed6ddc40926f5464f38bb49978 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c979b08a41690d1a30c9f4a050f1f5f2 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_edc84a9c07f150bc80470179e02ae2f6 = $(`&lt;div id=&quot;html_edc84a9c07f150bc80470179e02ae2f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;             &lt;b&gt;ID:&lt;/b&gt; F002&lt;br&gt;             &lt;b&gt;Type:&lt;/b&gt; Transformer Failure&lt;br&gt;             &lt;b&gt;Voltage:&lt;/b&gt; 1800 V&lt;br&gt;             &lt;b&gt;Current:&lt;/b&gt; 180 A&lt;br&gt;             &lt;b&gt;Load:&lt;/b&gt; 45 MW         &lt;/div&gt;`)[0];
#                 popup_c979b08a41690d1a30c9f4a050f1f5f2.setContent(html_edc84a9c07f150bc80470179e02ae2f6);
#
#
#
#         marker_2ea2c2de29bd89017e76f500eb1e2a53.bindPopup(popup_c979b08a41690d1a30c9f4a050f1f5f2)
#         ;
#
#
#
#
#                 marker_2ea2c2de29bd89017e76f500eb1e2a53.setIcon(icon_8b1f7bed6ddc40926f5464f38bb49978);
#
#
#             var marker_40798866f3f8a3d316760119c737a538 = L.marker(
#                 [34.0525, -118.244],
#                 {
# }
#             ).addTo(map_9b6101db0767f07f7becda18e32e9af9);
#
#
#             var icon_19efce2eb893535edf20e92324157375 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;bolt&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6f5b0bf762658f40d29b77e628062f03 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e799f2f490ee15163636faa1a21d1201 = $(`&lt;div id=&quot;html_e799f2f490ee15163636faa1a21d1201&quot; style=&quot;width: 100.0%; height: 100.0%

# %% [markdown]
# ### Cluster Map for the Data

# %%
map2 = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)
marker_cluster = MarkerCluster().add_to(map2)

for _, row in df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"{row['Fault ID']} - {row['Fault Type']}",
        icon=folium.Icon(color="green", icon="info-sign")
    ).add_to(marker_cluster)

# map2.save("folium_cluster_map.html")
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b3787f03d97e1b1351aacd8152e6a90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b3787f03d97e1b1351aacd8152e6a90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b3787f03d97e1b1351aacd8152e6a90 = L.map(
#                 &quot;map_0b3787f03d97e1b1351aacd8152e6a90&quot;,
#                 {
#                     center: [34.49962312252965, -118.48780849802372],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ed1953d813f8dcffe5757dadae564d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ed1953d813f8dcffe5757dadae564d8.addTo(map_0b3787f03d97e1b1351aacd8152e6a90);
#
#
#             var marker_cluster_5274fdd08cafa1913a385af8b5e8f7a8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_bd64e2dbbbe08ae13519feeda993a8f8 = L.marker(
#                 [34.0522, -118.2437],
#                 {
# }
#             ).addTo(marker_cluster_5274fdd08cafa1913a385af8b5e8f7a8);
#
#
#             var icon_3b55b81a3935006f8e4a61a2ced90150 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d799a4463123a0e586096d8860bbc054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee333289e02f2d30d305412841a808a4 = $(`&lt;div id=&quot;html_ee333289e02f2d30d305412841a808a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;F001 - Line Breakage&lt;/div&gt;`)[0];
#                 popup_d799a4463123a0e586096d8860bbc054.setContent(html_ee333289e02f2d30d305412841a808a4);
#
#
#
#         marker_bd64e2dbbbe08ae13519feeda993a8f8.bindPopup(popup_d799a4463123a0e586096d8860bbc054)
#         ;
#
#
#
#
#                 marker_bd64e2dbbbe08ae13519feeda993a8f8.setIcon(icon_3b55b81a3935006f8e4a61a2ced90150);
#
#
#             var marker_198c304fff286a2e45b8e323d2810651 = L.marker(
#                 [34.056, -118.245],
#                 {
# }
#             ).addTo(marker_cluster_5274fdd08cafa1913a385af8b5e8f7a8);
#
#
#             var icon_df7154ab498d8d66201b8a59dadf4765 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82c0a162c54ebc233efc6feb7bf71b0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68b40144f2e2c2c0232a8751932e5fc0 = $(`&lt;div id=&quot;html_68b40144f2e2c2c0232a8751932e5fc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;F002 - Transformer Failure&lt;/div&gt;`)[0];
#                 popup_82c0a162c54ebc233efc6feb7bf71b0b.setContent(html_68b40144f2e2c2c0232a8751932e5fc0);
#
#
#
#         marker_198c304fff286a2e45b8e323d2810651.bindPopup(popup_82c0a162c54ebc233efc6feb7bf71b0b)
#         ;
#
#
#
#
#                 marker_198c304fff286a2e45b8e323d2810651.setIcon(icon_df7154ab498d8d66201b8a59dadf4765);
#
#
#             var marker_3354943722e8b4b3943aed12b1413a50 = L.marker(
#                 [34.0525, -118.244],
#                 {
# }
#             ).addTo(marker_cluster_5274fdd08cafa1913a385af8b5e8f7a8);
#
#
#             var icon_50d191e0fd1aecb99b1e736a793f7a8b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7e709610fcd3abe71e5fb7f4a55ecb7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# ### Bubble Map
#
# Based on Duration of Fault (hrs) Discretized into 3 Bins

# %%
# Bin durations
df['Duration_Bin'] = pd.cut(df['Duration of Fault (hrs)'], bins=3, labels=["Short", "Medium", "Long"])

map3 = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5 + row['Duration of Fault (hrs)'],  # Bubble size
        color="crimson",
        fill=True,
        fill_opacity=0.6,
        popup=f"{row['Fault ID']} - Duration: {row['Duration of Fault (hrs)']} hrs ({row['Duration_Bin']})"
    ).add_to(map3)

# map3.save("folium_bubble_duration_map.html")
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a53ed5880007df30ca794f9594c54be0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a53ed5880007df30ca794f9594c54be0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a53ed5880007df30ca794f9594c54be0 = L.map(
#                 &quot;map_a53ed5880007df30ca794f9594c54be0&quot;,
#                 {
#                     center: [34.49962312252965, -118.48780849802372],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29687b31237706f90145a4a34e86d5fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29687b31237706f90145a4a34e86d5fa.addTo(map_a53ed5880007df30ca794f9594c54be0);
#
#
#             var circle_marker_f0c601e4449fc953148f6eb2bd6f2037 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a53ed5880007df30ca794f9594c54be0);
#
#
#         var popup_fee12befc28b2015c0f6fe149553b4e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6b87fd626c18e932635d8f72978d698 = $(`&lt;div id=&quot;html_a6b87fd626c18e932635d8f72978d698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;F001 - Duration: 2.0 hrs (Short)&lt;/div&gt;`)[0];
#                 popup_fee12befc28b2015c0f6fe149553b4e0.setContent(html_a6b87fd626c18e932635d8f72978d698);
#
#
#
#         circle_marker_f0c601e4449fc953148f6eb2bd6f2037.bindPopup(popup_fee12befc28b2015c0f6fe149553b4e0)
#         ;
#
#
#
#
#             var circle_marker_d7f9dcc6e0cd566788576f5698c7aef9 = L.circleMarker(
#                 [34.056, -118.245],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a53ed5880007df30ca794f9594c54be0);
#
#
#         var popup_a4cb8477038cbf0879a5c2bcaeb04196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b01d40a684362f6347b3a28f9cd9edb4 = $(`&lt;div id=&quot;html_b01d40a684362f6347b3a28f9cd9edb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;F002 - Duration: 3.0 hrs (Short)&lt;/div&gt;`)[0];
#                 popup_a4cb8477038cbf0879a5c2bcaeb04196.setContent(html_b01d40a684362f6347b3a28f9cd9edb4);
#
#
#
#         circle_marker_d7f9dcc6e0cd566788576f5698c7aef9.bindPopup(popup_a4cb8477038cbf0879a5c2bcaeb04196)
#         ;
#
#
#
#
#             var circle_marker_682fffe9bccfa0978fb04fcac0bce074 = L.circleMarker(
#                 [34.0525, -118.244],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a53ed5880007df30ca794f9594c54be0);
#
#
#         var popup_2aec146da8fe7db15f5f799bc8ee6a4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5df14fee1680e1b6cfebb15a822534f5 = $(`&lt;div id=&quot;html_5df14fee1680e1b6cfebb15a822534f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;F003 - Duration: 4.0 hrs (Medium)&lt;/div&gt;`)[0];
#                 popup_2aec146da8fe7db15f5f799bc8ee6a4a.setContent(html_5df14fee1680e1b6cfebb15a822534f5);
#
#
#
#         circle_marker_682fffe9bccfa0978fb04fcac0bce074.bindPopup(popup_2aec146da8fe7db15f5f799bc8ee6a4a)
#         ;

# %% [markdown]
# ### Heat Map
#
# Based on Down time (hrs) Discretized into 3 Bins

# %%
# Prepare heatmap data with weight = downtime
heat_data = [[row['Latitude'], row['Longitude'], row['Down time (hrs)']] for _, row in df.iterrows()]

map5 = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=10)
HeatMap(heat_data, radius=15, blur=10, max_zoom=1).add_to(map5)

# map5.save("folium_heatmap.html")
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a2191edf4a011127a93fa157bbf9c42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a2191edf4a011127a93fa157bbf9c42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a2191edf4a011127a93fa157bbf9c42 = L.map(
#                 &quot;map_8a2191edf4a011127a93fa157bbf9c42&quot;,
#                 {
#                     center: [34.49962312252965, -118.48780849802372],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d8675e67c135644fa72f93d56003608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d8675e67c135644fa72f93d56003608.addTo(map_8a2191edf4a011127a93fa157bbf9c42);
#
#
#             var heat_map_647bc92be927a41baa934eddc1e1b754 = L.heatLayer(
#                 [[34.0522, -118.2437, 1.0], [34.056, -118.245, 5.0], [34.0525, -118.244, 6.0], [34.055, -118.242, 3.0], [34.0545, -118.243, 4.0], [34.05, -118.24, 7.0], [34.9449, -118.9839, 6.1], [34.2294, -118.2988, 2.1], [34.1279, -118.8442, 4.7], [34.4192, -118.8254, 2.8], [34.3732, -118.1586, 1.9], [34.0465, -118.623, 6.9], [34.9687, -118.5356, 6.4], [34.3229, -118.46, 5.8], [34.2256, -118.9178, 5.0], [34.7105, -118.5379, 1.9], [34.9346, -118.9658, 6.0], [34.1619, -118.6775, 3.7], [34.5459, -118.8822, 3.7], [34.668, -118.6576, 6.9], [34.1203, -118.2873, 5.9], [34.1949, -118.16, 4.2], [34.3627, -118.7696, 6.2], [34.8432, -118.2489, 6.4], [34.8937, -118.532, 5.4], [34.9593, -118.9408, 3.3], [34.2486, -118.6496, 1.9], [34.7606, -118.9892, 2.8], [34.5413, -118.39, 3.6], [34.8762, -118.3086, 4.6], [34.2413, -118.15, 6.4], [34.5078, -118.5804, 4.0], [34.4338, -118.7342, 5.0], [34.6017, -118.4097, 6.4], [34.8153, -118.2817, 5.9], [34.7444, -118.5682, 6.5], [34.7291, -118.1506, 2.9], [34.991, -118.7368, 5.7], [34.8447, -118.1434, 1.5], [34.3129, -118.5028, 5.5], [34.3228, -118.8885, 4.7], [34.1986, -118.9095, 3.3], [34.8146, -118.1125, 7.0], [34.4945, -118.1668, 6.8], [34.4833, -118.5611, 4.5], [34.7468, -118.2933, 6.7], [34.3217, -118.1726, 2.9], [34.2278, -118.6517, 4.0], [34.0647, -118.0042, 5.1], [34.9547, -118.7239, 2.9], [34.6747, -118.6695, 1.3], [34.5874, -118.2254, 6.9], [34.0295, -118.0712, 3.3], [34.3813, -118.5256, 2.5], [34.1846, -118.5986, 1.1], [34.0609, -118.4429, 2.8], [34.5634, -118.1406, 3.1], [34.9126, -118.4003, 6.6], [34.8072, -118.6883, 4.6], [34.92, -118.0622, 1.8], [34.1883, -118.5957, 6.5], [34.5751, -118.4681, 2.8], [34.4263, -118.5649, 2.8], [34.7708, -118.3011, 4.8], [34.048, -118.972, 5.4], [34.8492, -118.4913, 5.3], [34.2067, -118.3596, 6.5], [34.9844, -118.0129, 5.0], [34.6804, -118.2898, 3.5], [34.8426, -118.8105, 1.8], [34.223, -118.3624, 2.5], [34.715, -118.305, 6.3], [34.9502, -118.4453, 1.2], [34.1845, -118.2375, 4.6], [34.6629, -118.4964, 6.7], [34.3501, -118.7994, 4.8], [34.658, -118.5611, 4.3], [34.0567, -118.3152, 1.9], [34.6843, -118.9941, 1.4], [34.824, -118.5236, 4.7], [34.9801, -118.3633, 2.0], [34.9991, -118.1181, 4.2], [34.9875, -118.875, 6.7], [34.3636, -118.674, 6.7], [34.6593, -118.3811, 1.7], [34.4523, -118.0953, 6.6], [34.1803, -118.557, 1.9], [34.5751, -118.1992, 5.6], [34.7353, -118.1241, 2.9], [34.203, -118.8494, 5.2], [34.3032, -118.1977, 4.3], [34.6999, -118.7188, 3.8], [34.1705, -118.98, 6.7], [34.3438, -118.6602, 1.9], [34.1971, -118.3658, 2.0], [34.192, -118.7198, 2.6], [34.3375, -118.7272, 6.6], [34.7346, -118.9808, 3.3], [34.8031, -118.1464, 3.9], [34.0833, -118.5501, 1.6], [34.1771, -118.935, 4.7], [34.5828, -118.0344, 2.2], [34.9266, -118.8144, 2.9], [34.1926, -118.1824, 6.2], [34.1849, -118.9937, 5.6], [34.187, -118.6786, 2.7], [34.2509, -118.6552, 4.0], [34.0604, -118.2443, 6.5], [34.6811, -118.3218, 3.9], [34.9991, -118.8097, 6.1], [34.4636, -118.1009, 6.2], [34.3994, -118.986, 1.9], [34.1978, -118.5027, 3.6], [34.4873, -118.3342, 6.7], [34.4163, -118.987, 1.8], [34.3411, -118.6266, 2.5], [34.6883, -118.0899, 5.2], [34.9655, -118.2184, 1.1], [34.8807, -118.6159, 3.7], [34.7913, -118.7238, 5.9], [34.5619, -118.2163, 6.5], [34.1204, -118.2666, 6.1], [34.261, -118.8559, 7.0], [34.6259, -118.4447, 3.7], [34.5865, -118.6772, 5.3], [34.0255, -118.5657, 5.5], [34.8833, -118.9441, 6.6], [34.0919, -118.6397, 4.1], [34.7897, -118.3054, 4.9], [34.0242, -118.3571, 1.8], [34.323, -118.244, 3.5], [34.0401, -118.4103, 3.2], [34.3972, -118.8477, 5.5], [34.3345, -118.6729, 4.9], [34.77, -118.7954, 6.0], [34.2143, -118.4067, 1.1

# %% [markdown]
# ***
# ### 📍 **More information**
# For more information, see Alaa Khamis, [Handling Geospatial Data and Mapping in Python](https://medium.com/ai4sm/handling-geospatial-data-and-mapping-in-python-5e63326a13d5), Medium, August 31, 2023.
